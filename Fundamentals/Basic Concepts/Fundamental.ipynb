# %%
x=10
y=20
z=30

x,y,z = 10,20,30
print(x,y,z)
# Out:
# 10 20 30

# %%
total_sum = 10+20\
            +30+40+50
total_sum
# Out:
# 150

# %%
a= 10
b="10"

b_new= int(b)
a_new = str(a)

print(type(b))
print(type(b_new))
print(type(a))
print(type(a_new))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>

# %%
name="Anish Shakya"

print(name.upper())
print(name.lower())
# Out:
# ANISH SHAKYA
# anish shakya

# %%
print(name.capitalize())
# Out:
# Anish shakya

# %%
print(name.replace("An","Bo"))
# Out:
# Boish Shakya

# %%
x = "Anish Shakya Text"
print(x.split(" "))
# Out:
# ['Anish', 'Shakya', 'Text']

# %%
file="raw_data.csv"

if file.endswith(".csv"):
    print("csv file")
# Out:
# csv file

# %%
x = "Anish Shakya Text"
print(x.partition("Shakya"))
# Out:
# ('Anish ', 'Shakya', ' Text')

# %%
statement =" Hello Anish. What are you doing. Hey Anish I am taking to you."

print(statement.count('Anish'))
# Out:
# 2

# %%
demo_str = "Hello"

demo_var = "10"
demo_var2 = "10dsdsad"

print(demo_str.isnumeric())
print(demo_str.isalpha())
print(demo_var.isnumeric())
print(demo_var2.isalnum())
# Out:
# False
# True
# True
# True
