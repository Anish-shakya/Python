# %%
## If Statement

x=10

if(x==10):
    if(x<5):
        print(f'X is less than 5')
    elif((x>5) & (x<10)):
        print('X is between 5 and 10')
    else:
        print("X is equal 10")
elif(x>100):
    print(f'X is too Big')
else:
    print(f'X is not 10')
# Out:
# X is equal 10
